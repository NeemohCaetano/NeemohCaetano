# %%
import pandas as pd
import numpy as np
import datetime

# %%
import os

# %%
pwd = os.getcwd()

# %%
filepath = pwd + "/netflix_titles.csv" # This creates a string that is the filepath to the simple_csv file

# %%
netflix = pd.read_csv(filepath) # This reads the csv into Python
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
list(netflix.columns) #This will list all of the columns in the dataset
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'release_year',
#  'rating',
#  'duration',
#  'listed_in',
#  'description']

# %%
netflix.describe()
# Out:
#        release_year
# count   7787.000000
# mean    2013.932580
# std        8.757395
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2018.000000
# max     2021.000000

# %%
list(netflix["country"].unique()) #Unique values in a column
# Out:
# ['Brazil',
#  'Mexico',
#  'Singapore',
#  'United States',
#  'Turkey',
#  'Egypt',
#  'India',
#  'Poland, United States',
#  'Thailand',
#  'Nigeria',
#  nan,
#  'Norway, Iceland, United States',
#  'United Kingdom',
#  'Japan',
#  'South Korea',
#  'Italy',
#  'Canada',
#  'Indonesia',
#  'Romania',
#  'Spain',
#  'Iceland',
#  'South Africa, Nigeria',
#  'France',
#  'United States, South Africa',
#  'Portugal, Spain',
#  'Hong Kong, China, Singapore',
#  'United States, Germany',
#  'South Africa, China, United States',
#  'Argentina',
#  'United States, France, Serbia',
#  'Germany',
#  'Denmark, France, Poland',
#  'Poland',
#  'Kenya',
#  'New Zealand, United Kingdom',
#  'Pakistan',
#  'Australia',
#  'Australia, United States',
#  'Mexico, United States',
#  'United States, China',
#  'China, Hong Kong',
#  'Taiwan',
#  'United States, United Kingdom',
#  'France, South Korea, Japan',
#  'United States, Canada',
#  'United Kingdom, United States',
# ...

# %%
netflix[netflix["country"] == "Singapore"]  #filter a dataframe
# Out:
#      show_id     type                           title       director  \
# 2         s3    Movie                           23:59   Gilbert Chan
# 333     s334  TV Show                Against the Tide            NaN
# 511     s512    Movie          André & his olive tree      Josiah Ng
# 1064   s1065  TV Show             Bountiful Blessings            NaN
# 2093   s2094    Movie      Fakkah Fuzz: Almost Banned  Michael McKay
# 2956   s2957    Movie                       Imperfect    Steve Cheng
# 3528   s3529    Movie                       Lang Tong        Sam Loh
# 4106   s4107  TV Show                       Mind Game            NaN
# 4138   s4139    Movie  Miss J Contemplates Her Choice      Jason Lai
# 4375   s4376  TV Show                 Mystic Whispers            NaN
# 5870   s5871  TV Show                          Sudden            NaN
# 6087   s6088  TV Show                   The Apartment            NaN
# 6311   s6312  TV Show              The Dream Catchers            NaN
# ...

# %%
netflix[(netflix["country"] == "Singapore") & (netflix["rating"] == "TV-MA")] #filter a data frame with multiple conditions
# Out:
#      show_id     type                           title       director  \
# 2093   s2094    Movie      Fakkah Fuzz: Almost Banned  Michael McKay
# 2956   s2957    Movie                       Imperfect    Steve Cheng
# 3528   s3529    Movie                       Lang Tong        Sam Loh
# 4138   s4139    Movie  Miss J Contemplates Her Choice      Jason Lai
# 6949   s6950  TV Show               The Truth Seekers            NaN
#
#                                                    cast    country  \
# 2093                                        Fakkah Fuzz  Singapore
# 2956  Edwin Goh, Ian Fang Weijie, Phua Yida, Kimberl...  Singapore
# 3528  William Lawandi, Angeline Yap, Vivienne Tseng,...  Singapore
# 4138  Kit Chan, Xiang Yun, Bobby Tonelli, Shane Pow,...  Singapore
# 6949  Chen Hanwei, Rebecca Lim, Desmond Tan, Yusuke ...  Singapore
#
#              date_added  release_year rating  duration  \
# 2093   January 26, 2018          2018  TV-MA    61 min
# ...

# %%
netflix["computer_date"] = pd.to_datetime(netflix["date_added"])
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
from datetime import datetime as dt
netflix["computer_date"].fillna(dt(2020, 1, 1), inplace=True)

# %%
netflix[["Date Part 1", "Date Part 2"]] = netflix["date_added"].str.split(", ", expand=True)

# %%
netflix.rename(columns={"Date Part 2": "Year"}, inplace=True)

# %%
netflix["cast"].fillna(value="no cast info", inplace=True)
netflix["director"].fillna(value="no director info", inplace=True)

# %%
netflix["genre_count"] = netflix["listed_in"].map(lambda x: len(x.split(","))) #split "," is used to divide where to stop counting and start again

# %%
movies_by_country = netflix.groupby("country")["show_id"].count().reset_index().sort_values(by = "show_id", ascending = False).reset_index()

# %%
netflix.to_csv("netflix_titles_cleaned.csv", index=False) #this saves the changes
